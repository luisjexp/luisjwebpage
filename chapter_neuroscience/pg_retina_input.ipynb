# %% [markdown]
# SEE POWERPOINT VERSION - MOVE POWER POINT SLIDES TO HERE IF YOU WANT TO PRESENT ON WEBSITE. OR CONVERT EACH SLIDE TO IMAGE, THEN PASTE HERE
#
#
# ## The Eye: Pupil: Dilation + contraction of pupil
# ![slide from neuro 119M](../assets/slides_opticalsystemppt_dilation_and_contraction_of_pupil.png)

# %% [markdown]
# # The Eye: Retina
# <figure style="float: right; width: 50%;">
#   <img src="../assets/2004kalat_fig51_table_fovealAndPeripheralVision.png" alt="Description of the image" style="width: 100%; height: auto;">
#   <figcaption style="text-align: center; font-size: 0.8em; color: gray;">
#     Kalat 2004, Biological Psychology.
#   </figcaption>
# </figure>
#
# - Layers + cells, breif description of
#   - what each is + does
#   - signaling pathway
